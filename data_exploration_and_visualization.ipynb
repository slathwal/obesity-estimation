# %% [markdown]
# # Preliminary Data Exploration and Visualization

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the obesity dataset
file_path = './data/raw/ObesityDataSet_raw_and_data_sinthetic.csv'
obesity = pd.read_csv(file_path)

# Check for missing values in the dataset
print(obesity.isnull().sum())

# Display the first few rows of the dataset
obesity.head()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
# Display dataset information
obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
#  16  NObeyesdad                      2111 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 280.5+ KB

# %%
# Analyze the distribution of the target variable
obesity.NObeyesdad.value_counts()
# Out:
# NObeyesdad
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %% [markdown]
# ## Plot target histogram

# %%
# Change the target name from "NObeyesdad" to "target"
obesity.rename(columns={"NObeyesdad": "Target"}, inplace=True)

# Count occurrences
feature = "Target"
counts = obesity[feature].value_counts().sort_index()

# %%
# Set seaborn properties
sns.set_theme(style="whitegrid")
sns.set_context("talk", font_scale=1.1)
plt.rcParams.update({
    "figure.dpi": 300,              # High-resolution output
    "axes.spines.top": False,
    "axes.spines.right": False,
    "axes.labelsize": 13,
    "axes.titlesize": 16,
    "axes.titleweight": "bold",
    "font.family": "serif",
    "savefig.bbox": "tight"
})

# %%
# Create horizontal bar plot
fig, ax = plt.subplots(figsize=(7,6))

# Define custom order for categories
custom_order = [
    "Insufficient_Weight", "Normal_Weight", "Overweight_Level_I",
    "Overweight_Level_II", "Obesity_Type_I", "Obesity_Type_II", "Obesity_Type_III"
]

# Plot horizontal bars
ordered_counts = counts.reindex(custom_order)

sns.barplot(
    y=counts.index,
    x=counts.values,
    hue=counts.index,
    palette="Set2",
    order=custom_order,
    legend=False,
    edgecolor="black",
    ax=ax
)

# Add value labels to bars (with spacing)
offset = ordered_counts.max() * 0.03  # move labels slightly to the right
for i, val in enumerate(ordered_counts.values):
    ax.text(val + offset, i, f"{val}", va="center", fontsize=11)

# Customize plot
ax.set_title(f"Distribution of {feature}", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Count", fontsize=11)
ax.set_ylabel("")
ax.set_xlim(0, ordered_counts.max() + ordered_counts.max()*0.15)  # auto padding

# Customize ticks
plt.xticks(fontsize=11)  
plt.yticks(fontsize=10)

# Finalize and save the plot
sns.despine()
plt.tight_layout()
plt.savefig(f"{feature}_distribution_horizontal_bar.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Interpretation: the target is quite balance so we have no imbalance problem here. Overweight and Obesity categories have higher counts compared to Insufficient or Normal weight

# %% [markdown]
# ## Plot Target vs Age

# %%
# Display the first row of the dataset
obesity.head(1)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
#
#    NCP       CAEC SMOKE  CH2O SCC  FAF  TUE CALC                 MTRANS  \
# 0  3.0  Sometimes    no   2.0  no  0.0  1.0   no  Public_Transportation
#
#           Target
# 0  Normal_Weight

# %%
obesity.Target.value_counts()
# Out:
# Target
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %%
# Visualize Age distribution by Target using violin plot
plt.figure(figsize=(8, 5))

# Define custom order for categories
custom_order = ["Insufficient_Weight", "Normal_Weight", "Overweight_Level_I", "Overweight_Level_II","Obesity_Type_I","Obesity_Type_II","Obesity_Type_III"]
ax = sns.violinplot(
    y="Target",
    x="Age",
    hue="Target",
    data=obesity,
    order=custom_order,
    palette="Set2",
    inner="quartile",
    legend=False
)

# Customize plot
plt.title("Age Distribution by Target", fontsize=16, fontweight="bold", pad=15)
plt.xlabel("Age", fontsize=12)
ax.set_ylabel("")  
ax.set_xlim(0, 70)

# Customize ticks
plt.xticks(fontsize=11)
plt.yticks(fontsize=10)

# Finalize and save the plot
sns.despine()
plt.tight_layout()
plt.savefig(f"age_distribution_by_target.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Interpretation: Insufficient weight mainly happened in younger ages. Normal weight is observed across a wide range of ages, but is most common among young to middle-aged adults (roughly early 20s to late 30s). Obesity Type II occurs around ages 20-35. Obesity Type III more concentrated in younger ages (around ~18–28).

# %% [markdown]
# ## Plot Target vs Weight

# %%
# Plot Weight distribution by Target using violin plot
plt.figure(figsize=(8, 5))

custom_order = ["Insufficient_Weight", "Normal_Weight", "Overweight_Level_I", "Overweight_Level_II","Obesity_Type_I","Obesity_Type_II","Obesity_Type_III"]
ax = sns.violinplot(
    y="Target",
    x="Weight",
    hue="Target",
    data=obesity,
    order=custom_order,
    palette="Set2",
    inner="quartile",
    legend=False
)

# Customize plot
plt.title("Weight Distribution by Target", fontsize=16, fontweight="bold", pad=15)
plt.xlabel("Weight", fontsize=12)
ax.set_ylabel("")  
ax.set_xlim(0, 200)

# Customize ticks
plt.xticks(fontsize=11)
plt.yticks(fontsize=10)

# Finalize and save the plot
sns.despine()
plt.tight_layout()
plt.savefig(f"Weight_distribution_by_target.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Interpretation: The plot clearly visualizes a positive relationship between weight and obesity level. Higher categories (from Overweight Level I to Obesity Type III) show both higher average weights and broader weight distributions, generally starting from around 100 kg. Individuals classified as obese typically have higher weights compared to those in the normal or overweight categories.

# %% [markdown]
# ## Plot Smoke vs Weight

# %%
# Analyze the distribution of the SMOKE feature
obesity.SMOKE.value_counts()
# Out:
# SMOKE
# no     2067
# yes      44
# Name: count, dtype: int64

# %%
# Plot Weight distribution by SMOKE using violin plot
plt.figure(figsize=(8, 5))

# custom_order = ["Insufficient_Weight", "Normal_Weight", "Overweight_Level_I", "Overweight_Level_II","Obesity_Type_I","Obesity_Type_II","Obesity_Type_III"]
ax = sns.violinplot(
    y="SMOKE",
    x="Weight",
    hue="SMOKE",
    data=obesity,
    #order=custom_order,
    palette="Set2",
    inner="quartile",
    legend=False
)

# Customize plot
plt.title("Weight Distribution by SMOKE", fontsize=16, fontweight="bold", pad=15)
plt.xlabel("Weight", fontsize=12)
ax.set_ylabel("")  
ax.set_xlim(0, 200)

# Customize ticks
plt.xticks(fontsize=11)
plt.yticks(fontsize=10)

# Finalize and save the plot
sns.despine()
plt.tight_layout()
plt.savefig(f"Weight_distribution_by_SMOKE.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Interpretation: The smokers generally have higher average weights and a broader range of weights than non-smokers.

# %% [markdown]
# ## Plot Smoke vs Age

# %%
plt.figure(figsize=(8, 5))

#custom_order = ["Insufficient_Weight", "Normal_Weight", "Overweight_Level_I", "Overweight_Level_II","Obesity_Type_I","Obesity_Type_II","Obesity_Type_III"]
ax = sns.violinplot(
    y="SMOKE",
    x="Age",
    hue="SMOKE",
    data=obesity,
    #order=custom_order,
    palette="Set2",
    inner="quartile",
    legend=False
)

# Customize plot
plt.title("Age Distribution by SMOKE", fontsize=16, fontweight="bold", pad=15)
plt.xlabel("Age", fontsize=12)
ax.set_ylabel("")  
ax.set_xlim(0, 75)

# Customize ticks
plt.xticks(fontsize=11)
plt.yticks(fontsize=10)

# Finalize and save the plot
sns.despine()
plt.tight_layout()
plt.savefig(f"Age_distribution_by_SMOKE.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Interpretation: The plot indicates that smokers generally have higher ages compared to non-smokers, suggesting that smoking is more common among older individuals.

# %% [markdown]
# ## Scatter Plot Age vs Weight

# %%
# Scatter plot of Age vs Weight colored by Target
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Define custom order
custom_order = [
    "Insufficient_Weight", "Normal_Weight", "Overweight_Level_I", 
    "Overweight_Level_II", "Obesity_Type_I", "Obesity_Type_II", "Obesity_Type_III"
]

# Convert Target to categorical with ordered categories
obesity["Target"] = pd.Categorical(obesity["Target"], categories=custom_order, ordered=True)

plt.figure(figsize=(7,5))
sns.set_theme(style="whitegrid")

ax = sns.scatterplot(
    data=obesity,
    x="Age",
    y="Weight",
    hue="Target",        
    palette="Set2",
    s=60,
    edgecolor="black",
    alpha=0.8
)

# Customize plot
ax.set_title("Relationship between Age and Weight by Target", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Age (years)", fontsize=13)
ax.set_ylabel("Weight (kg)", fontsize=13)

# Customize ticks
ax.legend(title="Target", fontsize=10, title_fontsize=11, frameon=False)

#  
sns.despine(trim=True)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()

plt.savefig("age_weight_scatter_publication.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Create Heatmap for Counting Correlation amongs the Numerical Features

# %%
# Select numerical columns only
numerical_df = obesity.select_dtypes(include=['int64', 'float64'])

# %%
# Calculate the correlations
corr = numerical_df.corr()

# %%
# Plot the heatmap
import numpy as np

plt.figure(figsize=(10, 8))
sns.set_theme(style="white")

mask = np.triu(np.ones_like(corr, dtype=bool))  # mask upper triangle

# Create the heatmap
ax = sns.heatmap(
    corr,
    mask=mask,
    cmap="coolwarm",          # or 'RdBu_r', 'vlag', 'YlGnBu'
    annot=True,               # show correlation values
    fmt=".2f",
    linewidths=0.5,
    cbar_kws={"shrink": 0.8, "label": "Correlation"},
    square=True
)

# Customize plot
ax.set_title("Correlation Heatmap of Numerical Features", fontsize=16, fontweight="bold", pad=15)
plt.xticks(fontsize=11, rotation=45, ha="right")
plt.yticks(fontsize=11, rotation=0)
plt.tight_layout()

# Save at high resolution
plt.savefig("correlation_heatmap_publication.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Interpretation: there are some signs of multicolinearity. For example the correlation between Weight and Height is 0.46. Solution: use tree based model for classification since tree based model can handle multicolinearity in the dataset.

# %% [markdown]
# ## Plot the UMAP to Find the Clustering of the Numerical Features

# %%
# Standardize numerical features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(numerical_df)

# %%
import umap.umap_ as umap

reducer = umap.UMAP(
    n_neighbors=15,     # smaller = more local structure
    min_dist=0.1,       # lower = tighter clusters
    n_components=2,     # 2D for visualization
    random_state=42
)

embedding = reducer.fit_transform(X_scaled)

# %%
umap_df = pd.DataFrame(embedding, columns=["UMAP1", "UMAP2"])
umap_df["Target"] = obesity["Target"]

# %%
plt.figure(figsize=(8, 6))
sns.set_theme(style="white")

# Define consistent color order (same as your previous plots)
custom_order = [
    "Insufficient_Weight", "Normal_Weight", "Overweight_Level_I",
    "Overweight_Level_II", "Obesity_Type_I", "Obesity_Type_II", "Obesity_Type_III"
]
palette = sns.color_palette("Set2", n_colors=len(custom_order))

ax = sns.scatterplot(
    data=umap_df,
    x="UMAP1", y="UMAP2",
    hue="Target",
    hue_order=custom_order,
    palette=palette,
    s=60,
    edgecolor="black",
    alpha=0.8
)

ax.set_title("UMAP Projection of Obesity Dataset", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("UMAP Dimension 1", fontsize=13)
ax.set_ylabel("UMAP Dimension 2", fontsize=13)

ax.legend(
    title="Target Class", 
    fontsize=10, 
    title_fontsize=11, 
    frameon=False,
    bbox_to_anchor=(1.05, 1), 
    loc='upper left'
)

sns.despine(trim=True)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()

plt.savefig("umap_obesity_publication.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Interpretation: For Obesity type II and type III classes, the cluster are easy to differentitate. Meanwhile the other 5 classes mix into one big cluster. The challenge hre for the classification model to differentiate these 5 classes that merged into one big cluster.
